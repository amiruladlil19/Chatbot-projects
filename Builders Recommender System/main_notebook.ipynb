# %% [markdown]
# 1. Importing packages

# %%
import tensorflow as tf
import json
import random
import pandas as pd
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
from keras.models import load_model
from keras.models import model_from_json

# %% [markdown]
# 2. NLTK and Importing the data

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
nltk.download('punkt')
with open('intents2.json') as file:
    data = json.load(file)
# Out:
# [nltk_data] Downloading package punkt to /home/oem/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# 3. Creating Training Data

# %%
words = []
classes = []
documents = []
ignore_words = ['?']
# loop through each sentence in our intents patterns
for intent in data['intents']:
    for pattern in intent['patterns']:
        # tokenize each word in the sentence
        w = nltk.word_tokenize(pattern)
        # add to our words list
        words.extend(w)
        # add to documents in our corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# stem and lower each word and remove duplicates
words = [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # stem each word - create base word, in attempt to represent related words
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])

# %% [markdown]
# 4. Save and Load Model

# %%
try:
    converter = tf.lite.TFLiteConverter.from_saved_model('saved_model')
    tflite_model = converter.convert()

    with open('model.tflite', 'wb') as f:
        f.write(tflite_model)

    model = load_model("saved_model")

except:
    tf.compat.v1.reset_default_graph()
    model = Sequential()
    model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(len(train_y[0]), activation='softmax'))

    sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    model.compile(loss='categorical_crossentropy',
                  optimizer=sgd, metrics=['accuracy'])

    model.fit(np.array(train_x), np.array(train_y),
              epochs=200, batch_size=5, verbose=1)
    model.save("saved_model")

    converter = tf.lite.TFLiteConverter.from_saved_model('saved_model')
    tflite_model = converter.convert()

    with open('model.tflite', 'wb') as f:
        f.write(tflite_model)
# Out:
# och 3/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8874 - accuracy: 0.2364
# Epoch 4/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8955 - accuracy: 0.2727
# Epoch 5/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7442 - accuracy: 0.4000
# Epoch 6/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6289 - accuracy: 0.4182
# Epoch 7/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5272 - accuracy: 0.5273
# Epoch 8/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.5095 - accuracy: 0.4727
# Epoch 9/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.3707 - accuracy: 0.5636
# Epoch 10/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.2641 - accuracy: 0.6545
# Epoch 11/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.1281 - accuracy: 0.6727
# Epoch 12/200
# 11/11 [==============================] - 0s 2ms/step - loss: 1.0561 - accuracy: 0.6909
# Epoch 13/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0331 - accuracy: 0.6727
# Epoch 14/200
# 11/11 [==============================] - 0s 3ms/step - loss: 1.0413 - accuracy: 0.6545
# Epoch 15/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8189 - accuracy: 0.7818
# Epoch 16/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8328 - accuracy: 0.6909
# Epoch 17/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.7571 - accuracy: 0.8000
# Epoch 18/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.8419 - accuracy: 0.6909
# Epoch 19/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.7818
# Epoch 20/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.6311 - accuracy: 0.8000
# Epoch 21/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5854 - accuracy: 0.8364
# Epoch 22/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5765 - accuracy: 0.8182
# Epoch 23/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5480 - accuracy: 0.8182
# Epoch 24/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4587 - accuracy: 0.8364
# Epoch 25/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.5223 - accuracy: 0.8545
# Epoch 26/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.8545
# Epoch 27/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3317 - accuracy: 0.9273
# Epoch 28/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3563 - accuracy: 0.9091
# Epoch 29/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.4025 - accuracy: 0.9091
# Epoch 30/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2927 - accuracy: 0.9455
# Epoch 31/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3683 - accuracy: 0.8727
# Epoch 32/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3582 - accuracy: 0.8727
# Epoch 33/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3879 - accuracy: 0.8364
# Epoch 34/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2920 - accuracy: 0.9091
# Epoch 35/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2986 - accuracy: 0.9091
# Epoch 36/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.8545
# Epoch 37/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3217 - accuracy: 0.8545
# Epoch 38/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2629 - accuracy: 0.9273
# Epoch 39/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2058 - accuracy: 0.9636
# Epoch 40/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2485 - accuracy: 0.9455
# Epoch 41/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2103 - accuracy: 0.9455
# Epoch 42/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2127 - accuracy: 0.9636
# Epoch 43/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2688 - accuracy: 0.9273
# Epoch 44/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2593 - accuracy: 0.8909
# Epoch 45/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.8909
# Epoch 46/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2945 - accuracy: 0.8909
# Epoch 47/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2227 - accuracy: 0.9455
# Epoch 48/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1709 - accuracy: 0.9818
# Epoch 49/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2143 - accuracy: 0.9273
# Epoch 50/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1954 - accuracy: 0.9455
# Epoch 51/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9636
# Epoch 52/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.9455
# Epoch 53/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2181 - accuracy: 0.9455
# Epoch 54/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1959 - accuracy: 0.9455
# Epoch 55/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1220 - accuracy: 0.9455
# Epoch 56/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2747 - accuracy: 0.9273
# Epoch 57/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9818
# Epoch 58/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1720 - accuracy: 0.9455
# Epoch 59/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1413 - accuracy: 0.9818
# Epoch 60/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9455
# Epoch 61/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1549 - accuracy: 0.9636
# Epoch 62/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2794 - accuracy: 0.9091
# Epoch 63/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1971 - accuracy: 0.9273
# Epoch 64/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0997 - accuracy: 0.9818
# Epoch 65/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.2560 - accuracy: 0.9273
# Epoch 66/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0851 - accuracy: 0.9818
# Epoch 67/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 0.9455
# Epoch 68/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9818
# Epoch 69/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1167 - accuracy: 0.9818
# Epoch 70/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1375 - accuracy: 0.9636
# Epoch 71/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0973 - accuracy: 1.0000
# Epoch 72/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1531 - accuracy: 0.9273
# Epoch 73/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 74/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0905 - accuracy: 0.9818
# Epoch 75/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0722 - accuracy: 1.0000
# Epoch 76/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1744 - accuracy: 0.9455
# Epoch 77/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1319 - accuracy: 0.9818
# Epoch 78/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1045 - accuracy: 0.9818
# Epoch 79/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1202 - accuracy: 0.9636
# Epoch 80/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0846 - accuracy: 0.9818
# Epoch 81/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1086 - accuracy: 0.9818
# Epoch 82/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0991 - accuracy: 0.9818
# Epoch 83/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9636
# Epoch 84/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0940 - accuracy: 0.9818
# Epoch 85/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9636
# Epoch 86/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1479 - accuracy: 0.9273
# Epoch 87/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0875 - accuracy: 0.9818
# Epoch 88/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0693 - accuracy: 0.9818
# Epoch 89/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9636
# Epoch 90/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0798 - accuracy: 0.9818
# Epoch 91/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.9636
# Epoch 92/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9455
# Epoch 93/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1080 - accuracy: 0.9455
# Epoch 94/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0998 - accuracy: 0.9818
# Epoch 95/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9818
# Epoch 96/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1044 - accuracy: 0.9636
# Epoch 97/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1507 - accuracy: 0.9273
# Epoch 98/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0670 - accuracy: 0.9818
# Epoch 99/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0702 - accuracy: 0.9818
# Epoch 100/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1040 - accuracy: 0.9636
# Epoch 101/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9818
# Epoch 102/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1091 - accuracy: 0.9636
# Epoch 103/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1243 - accuracy: 0.9636
# Epoch 104/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1460 - accuracy: 0.9455
# Epoch 105/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0832 - accuracy: 0.9818
# Epoch 106/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1496 - accuracy: 0.9818
# Epoch 107/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 0.9818
# Epoch 108/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0778 - accuracy: 0.9818
# Epoch 109/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 0.9818
# Epoch 110/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0978 - accuracy: 0.9818
# Epoch 111/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0604 - accuracy: 0.9818
# Epoch 112/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.9636
# Epoch 113/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1177 - accuracy: 0.9273
# Epoch 114/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0590 - accuracy: 0.9636
# Epoch 115/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9636
# Epoch 116/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0541 - accuracy: 1.0000
# Epoch 117/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 118/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1162 - accuracy: 0.9455
# Epoch 119/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0664 - accuracy: 0.9636
# Epoch 120/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9818
# Epoch 121/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1797 - accuracy: 0.8909
# Epoch 122/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0651 - accuracy: 0.9818
# Epoch 123/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9636
# Epoch 124/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 0.9818
# Epoch 125/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9636
# Epoch 126/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0940 - accuracy: 0.9818
# Epoch 127/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0997 - accuracy: 0.9636
# Epoch 128/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1024 - accuracy: 0.9455
# Epoch 129/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0944 - accuracy: 0.9455
# Epoch 130/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 0.9636
# Epoch 131/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 132/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9818
# Epoch 133/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1042 - accuracy: 0.9636
# Epoch 134/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0732 - accuracy: 0.9636
# Epoch 135/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0569 - accuracy: 0.9818
# Epoch 136/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 0.9455
# Epoch 137/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0591 - accuracy: 0.9818
# Epoch 138/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0937 - accuracy: 0.9455
# Epoch 139/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1268 - accuracy: 0.9455
# Epoch 140/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1502 - accuracy: 0.9273
# Epoch 141/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1100 - accuracy: 0.9636
# Epoch 142/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 143/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 0.9818
# Epoch 144/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9818
# Epoch 145/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0919 - accuracy: 0.9636
# Epoch 146/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 0.9818
# Epoch 147/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9818
# Epoch 148/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 0.9636
# Epoch 149/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9818
# Epoch 150/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.9636
# Epoch 151/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 152/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 0.9818
# Epoch 153/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0719 - accuracy: 0.9636
# Epoch 154/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1208 - accuracy: 0.9636
# Epoch 155/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 156/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0625 - accuracy: 0.9818
# Epoch 157/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.9636
# Epoch 158/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 159/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9636
# Epoch 160/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 161/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0860 - accuracy: 0.9636
# Epoch 162/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 0.9818
# Epoch 163/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9636
# Epoch 164/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0550 - accuracy: 0.9818
# Epoch 165/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0433 - accuracy: 0.9818
# Epoch 166/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9818
# Epoch 167/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9818
# Epoch 168/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.9636
# Epoch 169/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 170/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0661 - accuracy: 0.9818
# Epoch 171/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 0.9818
# Epoch 172/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 0.9818
# Epoch 173/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0556 - accuracy: 0.9636
# Epoch 174/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9636
# Epoch 175/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.9818
# Epoch 176/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 0.9636
# Epoch 177/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9818
# Epoch 178/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0535 - accuracy: 0.9818
# Epoch 179/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9455
# Epoch 180/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0491 - accuracy: 0.9818
# Epoch 181/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9818
# Epoch 182/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 0.9818
# Epoch 183/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1134 - accuracy: 0.9636
# Epoch 184/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0879 - accuracy: 0.9636
# Epoch 185/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 186/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 187/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0653 - accuracy: 1.0000
# Epoch 188/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0417 - accuracy: 0.9818
# Epoch 189/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9636
# Epoch 190/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 0.9818
# Epoch 191/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0674 - accuracy: 0.9636
# Epoch 192/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1091 - accuracy: 0.9636
# Epoch 193/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.1315 - accuracy: 0.9455
# Epoch 194/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0732 - accuracy: 0.9818
# Epoch 195/200
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 1.0000
# Epoch 196/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 0.9818
# Epoch 197/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9818
# Epoch 198/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0738 - accuracy: 0.9636
# Epoch 199/200
# 11/11 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.9818
# Epoch 200/200
# 11/11 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 1.0000
# INFO:tensorflow:Assets written to: saved_model/assets
# INFO:tensorflow:Assets written to: saved_model/assets

# %% [markdown]
# 5. Clean the sentence up and creating bag of words

# %%
def clean_up_sentence(sentence):
    # tokenize the pattern - split words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stem each word - create short form for word
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words
# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)  
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
    return(np.array(bag))

# %%
## 6. Classify sentences and search the builders based on their skills and rating

# %%
def classify_local(sentence):
    ERROR_THRESHOLD = 0.25
    
    # generate probabilities from the model
    input_data = pd.DataFrame([bow(sentence, words)], dtype=float, index=['input'])
    results = model.predict([input_data])[0]
    # filter out predictions below a threshold, and provide intent index
    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], str(r[1])))
    # return tuple of intent and probability
    
    return classes[r[0]]

# %%
def recommend():
    print("Ceritakan permasalahan Anda")
    while True:
        inp = input("Anda: ")

        tag = classify_local(inp)
        
        try:
            print(filter(tag, df))
        except:
            break
        break


def filter(order, df):
    for i in order:
        df_filtered = df[df['layanan'].str.contains(
            i, regex=False, case=False, na=False)]
    return df_filtered.where(df['Rating'] > 4.0).dropna().loc[:, 'KODE':].head(10)


df = pd.read_csv('capsdata.csv')

recommend()
# Out:
# Ceritakan permasalahan Anda
#    KODE     nama                                           alamat  \
# 18  T19      Ari  Kawasan Kota Lama No 8, Semarang, Kota Semarang
# 26  T27  Pramono                              Kaliwungu, Semarang
# 27  T28   Laskar                                Kemijen, Semarang
# 34  T35    Yudhi                               Bugangan, Semarang
# 38  T39    Yanto                               Pleburan, Semarang
#
#            layanan     Gaji  Rating  umur
# 18           Pintu  88442.0     5.0  30.0
# 26           Pintu  89900.0     4.5  29.0
# 27  Jendela, Pintu  88689.0     5.0  36.0
# 34           Pintu  87653.0     4.5  34.0
# 38           Pintu  88689.0     4.5  31.0
# Pintu
